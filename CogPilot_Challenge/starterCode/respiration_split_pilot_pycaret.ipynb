# %% [markdown]
# # Load packages and prepare data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sktime.transformations.panel.padder import PaddingTransformer
from sktime.transformations.panel.catch22 import Catch22

# %%
df_combined_subject = pd.read_pickle("..\\cleanedData\\df_combined_subject.pkl")

# %%
# perform train test split according by subject
# split into 5 different folds for CV
from sklearn.model_selection import GroupKFold
X_train, X_test, y_train, y_test = [], [], [], []
gss = GroupKFold(n_splits=5)
for train, test in gss.split(df_combined_subject["normalised_resp"], df_combined_subject["difficulty"], df_combined_subject["subject"]):
  X_train.append(df_combined_subject.loc[train,["normalised_resp"]])
  X_test.append(df_combined_subject.loc[test,["normalised_resp"]])
  y_train.append(df_combined_subject.loc[train,"difficulty"].astype("string"))
  y_test.append(df_combined_subject.loc[test,"difficulty"].astype("string"))

# %% [markdown]
# ## Prepare Catch22 dataset

# %%
# %%time
catch22 = PaddingTransformer() * Catch22()
X_train0_catch22 = catch22.fit_transform(X_train[0])
X_test0_catch22 = catch22.transform(X_test[0])
# Out:
# CPU times: total: 39min 3s
# Wall time: 42min 18s

# %%
X_train0_catch22["difficulty"] = y_train[0].values

# %%
X_train0_catch22.to_csv("..\\cleanedData\\X_train0_catch22.csv")
X_test0_catch22.to_csv("..\\cleanedData\\X_test0_catch22.csv")

# %% [markdown]
# # Modeling

# %%
from pycaret.classification import *
pycaret_class = setup(data = X_train0_catch22, target = "difficulty", session_id=42)
# Out:
# <style type="text/css">
# #T_7c45f_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c45f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c45f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c45f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c45f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c45f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c45f_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c45f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c45f_row1_col1" class="data row1 col1" >difficulty</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c45f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7c45f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c45f_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_7c45f_row3_col1" class="data row3 col1" >000: 0, 01B: 1, 02B: 2, 03B: 3, 04B: 4</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c45f_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7c45f_row4_col1" class="data row4 col1" >(389, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c45f_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7c45f_row5_col1" class="data row5 col1" >(389, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c45f_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7c45f_row6_col1" class="data row6 col1" >(272, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c45f_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7c45f_row7_col1" class="data row7 col1" >(117, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c45f_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7c45f_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c45f_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_7c45f_row9_col1" class="data row9 col1" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c45f_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_7c45f_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c45f_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_7c45f_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c45f_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_7c45f_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c45f_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_7c45f_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c45f_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_7c45f_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c45f_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_7c45f_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c45f_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_7c45f_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c45f_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_7c45f_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c45f_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_7c45f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7c45f_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_7c45f_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7c45f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7c45f_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_7c45f_row20_col1" class="data row20 col1" >9d0c</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_64282 th {
#   text-align: left;
# }
# #T_64282_row0_col0, #T_64282_row1_col0, #T_64282_row1_col1, #T_64282_row1_col2, #T_64282_row1_col3, #T_64282_row1_col4, #T_64282_row1_col5, #T_64282_row1_col6, #T_64282_row1_col7, #T_64282_row2_col0, #T_64282_row2_col1, #T_64282_row2_col2, #T_64282_row2_col3, #T_64282_row2_col4, #T_64282_row2_col5, #T_64282_row2_col6, #T_64282_row2_col7, #T_64282_row3_col0, #T_64282_row3_col1, #T_64282_row3_col2, #T_64282_row3_col3, #T_64282_row3_col4, #T_64282_row3_col5, #T_64282_row3_col6, #T_64282_row3_col7, #T_64282_row4_col0, #T_64282_row4_col1, #T_64282_row4_col2, #T_64282_row4_col3, #T_64282_row4_col4, #T_64282_row4_col5, #T_64282_row4_col6, #T_64282_row4_col7, #T_64282_row5_col0, #T_64282_row5_col1, #T_64282_row5_col2, #T_64282_row5_col3, #T_64282_row5_col4, #T_64282_row5_col5, #T_64282_row5_col6, #T_64282_row5_col7, #T_64282_row6_col0, #T_64282_row6_col1, #T_64282_row6_col2, #T_64282_row6_col3, #T_64282_row6_col4, #T_64282_row6_col5, #T_64282_row6_col6, #T_64282_row6_col7, #T_64282_row7_col0, #T_64282_row7_col1, #T_64282_row7_col2, #T_64282_row7_col3, #T_64282_row7_col4, #T_64282_row7_col5, #T_64282_row7_col6, #T_64282_row7_col7, #T_64282_row8_col0, #T_64282_row8_col1, #T_64282_row8_col2, #T_64282_row8_col3, #T_64282_row8_col4, #T_64282_row8_col5, #T_64282_row8_col6, #T_64282_row8_col7, #T_64282_row9_col0, #T_64282_row9_col1, #T_64282_row9_col2, #T_64282_row9_col3, #T_64282_row9_col4, #T_64282_row9_col5, #T_64282_row9_col6, #T_64282_row9_col7, #T_64282_row10_col0, #T_64282_row10_col1, #T_64282_row10_col2, #T_64282_row10_col3, #T_64282_row10_col4, #T_64282_row10_col5, #T_64282_row10_col6, #T_64282_row10_col7, #T_64282_row11_col0, #T_64282_row11_col1, #T_64282_row11_col2, #T_64282_row11_col3, #T_64282_row11_col4, #T_64282_row11_col5, #T_64282_row11_col6, #T_64282_row11_col7, #T_64282_row12_col0, #T_64282_row12_col1, #T_64282_row12_col2, #T_64282_row12_col3, #T_64282_row12_col4, #T_64282_row12_col5, #T_64282_row12_col6, #T_64282_row12_col7, #T_64282_row13_col0, #T_64282_row13_col1, #T_64282_row13_col2, #T_64282_row13_col3, #T_64282_row13_col4, #T_64282_row13_col5, #T_64282_row13_col6, #T_64282_row13_col7 {
#   text-align: left;
# }
# #T_64282_row0_col1, #T_64282_row0_col2, #T_64282_row0_col3, #T_64282_row0_col4, #T_64282_row0_col5, #T_64282_row0_col6, #T_64282_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_64282_row0_col8, #T_64282_row1_col8, #T_64282_row2_col8, #T_64282_row3_col8, #T_64282_row4_col8, #T_64282_row5_col8, #T_64282_row6_col8, #T_64282_row7_col8, #T_64282_row8_col8, #T_64282_row10_col8, #T_64282_row11_col8, #T_64282_row12_col8, #T_64282_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_64282_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_64282">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64282_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_64282_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_64282_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_64282_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_64282_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_64282_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_64282_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_64282_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_64282_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64282_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_64282_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_64282_row0_col1" class="data row0 col1" >0.3832</td>
#       <td id="T_64282_row0_col2" class="data row0 col2" >0.6457</td>
#       <td id="T_64282_row0_col3" class="data row0 col3" >0.3832</td>
#       <td id="T_64282_row0_col4" class="data row0 col4" >0.3808</td>
#       <td id="T_64282_row0_col5" class="data row0 col5" >0.3667</td>
#       <td id="T_64282_row0_col6" class="data row0 col6" >0.2252</td>
#       <td id="T_64282_row0_col7" class="data row0 col7" >0.2299</td>
#       <td id="T_64282_row0_col8" class="data row0 col8" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_64282_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_64282_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_64282_row1_col1" class="data row1 col1" >0.3562</td>
#       <td id="T_64282_row1_col2" class="data row1 col2" >0.6373</td>
#       <td id="T_64282_row1_col3" class="data row1 col3" >0.3562</td>
#       <td id="T_64282_row1_col4" class="data row1 col4" >0.3563</td>
#       <td id="T_64282_row1_col5" class="data row1 col5" >0.3440</td>
#       <td id="T_64282_row1_col6" class="data row1 col6" >0.1897</td>
#       <td id="T_64282_row1_col7" class="data row1 col7" >0.1932</td>
#       <td id="T_64282_row1_col8" class="data row1 col8" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_64282_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_64282_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_64282_row2_col1" class="data row2 col1" >0.3537</td>
#       <td id="T_64282_row2_col2" class="data row2 col2" >0.5915</td>
#       <td id="T_64282_row2_col3" class="data row2 col3" >0.3537</td>
#       <td id="T_64282_row2_col4" class="data row2 col4" >0.3434</td>
#       <td id="T_64282_row2_col5" class="data row2 col5" >0.3368</td>
#       <td id="T_64282_row2_col6" class="data row2 col6" >0.1876</td>
#       <td id="T_64282_row2_col7" class="data row2 col7" >0.1920</td>
#       <td id="T_64282_row2_col8" class="data row2 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_64282_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_64282_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_64282_row3_col1" class="data row3 col1" >0.3496</td>
#       <td id="T_64282_row3_col2" class="data row3 col2" >0.6275</td>
#       <td id="T_64282_row3_col3" class="data row3 col3" >0.3496</td>
#       <td id="T_64282_row3_col4" class="data row3 col4" >0.3460</td>
#       <td id="T_64282_row3_col5" class="data row3 col5" >0.3401</td>
#       <td id="T_64282_row3_col6" class="data row3 col6" >0.1832</td>
#       <td id="T_64282_row3_col7" class="data row3 col7" >0.1865</td>
#       <td id="T_64282_row3_col8" class="data row3 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_64282_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_64282_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_64282_row4_col1" class="data row4 col1" >0.3421</td>
#       <td id="T_64282_row4_col2" class="data row4 col2" >0.6436</td>
#       <td id="T_64282_row4_col3" class="data row4 col3" >0.3421</td>
#       <td id="T_64282_row4_col4" class="data row4 col4" >0.3469</td>
#       <td id="T_64282_row4_col5" class="data row4 col5" >0.3280</td>
#       <td id="T_64282_row4_col6" class="data row4 col6" >0.1712</td>
#       <td id="T_64282_row4_col7" class="data row4 col7" >0.1758</td>
#       <td id="T_64282_row4_col8" class="data row4 col8" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_64282_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_64282_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_64282_row5_col1" class="data row5 col1" >0.2976</td>
#       <td id="T_64282_row5_col2" class="data row5 col2" >0.5918</td>
#       <td id="T_64282_row5_col3" class="data row5 col3" >0.2976</td>
#       <td id="T_64282_row5_col4" class="data row5 col4" >0.2943</td>
#       <td id="T_64282_row5_col5" class="data row5 col5" >0.2813</td>
#       <td id="T_64282_row5_col6" class="data row5 col6" >0.1174</td>
#       <td id="T_64282_row5_col7" class="data row5 col7" >0.1218</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
