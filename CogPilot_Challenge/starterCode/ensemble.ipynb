# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df_combined_all = pd.read_csv("df_combined_all.csv")

# %%
df_combined_all = df_combined_all.dropna()

# %%
df_combined_all
# Out:
#     subject  run  resp_000  resp_01B  resp_02B  resp_03B  resp_04B difficulty  \
# 68    cp003    1     0.000     0.875     0.025     0.025     0.075        01B
# 69    cp003    2     0.025     0.625     0.050     0.075     0.225        01B
# 70    cp003    3     0.050     0.750     0.100     0.050     0.050        01B
# 80    cp008    1     0.000     0.475     0.250     0.175     0.100        01B
# 81    cp008    2     0.025     0.600     0.150     0.100     0.125        01B
# ..      ...  ...       ...       ...       ...       ...       ...        ...
# 482   cp042    2     0.625     0.275     0.075     0.025     0.000        04B
# 483   cp042    3     0.000     0.075     0.300     0.550     0.075        04B
# 484   cp043    1     0.000     0.200     0.300     0.475     0.025        04B
# 485   cp043    2     0.000     0.125     0.325     0.525     0.025        04B
# 486   cp043    3     0.000     0.250     0.175     0.550     0.025        04B
#
# ...

# %%
from pycaret.classification import *
pycaret_class = setup(data = df_combined_all, target = "difficulty", ignore_features=["resp_000", "subject", "run"], session_id=42)
# Out:
# <style type="text/css">
# #T_bee46_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bee46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bee46_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bee46_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bee46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bee46_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bee46_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_bee46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bee46_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bee46_row1_col1" class="data row1 col1" >difficulty</td>
#     </tr>
#     <tr>
#       <th id="T_bee46_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_2b5df th {
#   text-align: left;
# }
# ...
