# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
x, sr = librosa.load('T1_audio.wav')

# %%
print(x.shape, sr)
# Out:
# (584766,) 22050

# %%
x
# Out:
# array([-2.2130685e-05, -4.0208281e-05, -1.0713178e-05, ...,
#        -2.4200053e-06, -2.3992461e-05, -3.3187345e-05], dtype=float32)

# %%
x[::-1]
# Out:
# array([-3.3187345e-05, -2.3992461e-05, -2.4200053e-06, ...,
#        -1.0713178e-05, -4.0208281e-05, -2.2130685e-05], dtype=float32)

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x[::-1], sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
import IPython.display as ipd
ipd.Audio(x[::-1], rate=sr) # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# lat 67.9222 deg north
# lon 26.5046 deg east

# %% [markdown]
# The answer is 99600 Sodankylä, Finland
